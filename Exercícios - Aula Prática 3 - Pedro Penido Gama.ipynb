# %% [markdown]
# PRATICA 2 CREDITCARD
# ALUNO: PEDRO PENIDO GAMA
# MATRICULA: 149820

# %% [markdown]
# # LEITURA DF

# %%
#Montando disco no colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Bibliotecas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#leitura do arquivo no googledrive
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Modelagem e preparacao/creditcard/creditcard_transformed.csv')

# %%
#Conhecendo o arquivo lido
df
# Out:
#                X1         X2  Y
# 0        1.359780   0.071828  0
# 1       -1.191891  -0.265616  0
# 2        1.358334   1.340460  0
# 3        0.966301   0.185586  0
# 4        1.158246  -0.877576  0
# ...           ...        ... ..
# 284802  11.881180 -10.070988  0
# 284803   0.732786   0.055567  0
# 284804  -1.919607   0.300897  0
# 284805   0.240429  -0.531824  0
# 284806   0.533430   0.189495  0
#
# [284807 rows x 3 columns]

# %% [markdown]
# Classe 0 majoitaria, classe 1 minoritaria.

# %% [markdown]
# # UNDERSAMPLING

# %% [markdown]
# SAO AS TECNICAS DE UNDERSAMPLING:
# 1.   Random
# 2.   CNN
# 3.   Tomek Links
# 4.   ENN
# 5.   OSS
# 6.   NCR

# %% [markdown]
# ## 1. Random

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# example of random undersampling to balance the class distribution
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from matplotlib import pyplot
from numpy import where
# summarize class distribution
counter = Counter(y)
print(counter)
# Before scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define undersample strategy
undersample = RandomUnderSampler(sampling_strategy='majority')
# fit and apply the transform
X, y = undersample.fit_resample(X, y)
# summarize class distribution
counter = Counter(y)
print(counter)
# Before scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 492, 1: 492})

# %% [markdown]
# ## 2. CNN

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the Condensed Nearest Neighbor Rule
from collections import Counter
from imblearn.under_sampling import CondensedNearestNeighbour
from matplotlib import pyplot
from numpy import where
# summarize class distribution
counter = Counter(y)
print(counter)
# Before scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the undersampling method
undersample = CondensedNearestNeighbour(n_neighbors=1)
# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# After scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-84133ea160c0> in <module>()
#      17 undersample = CondensedNearestNeighbour(n_neighbors=1)
#      18 # transform the dataset
# ---> 19 X, y = undersample.fit_resample(X, y)
#      20 # summarize the new class distribution
#      21 counter = Counter(y)
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (
#
# /usr/local/lib/python3.7/dist-packages/imblearn/under_sampling/_prototype_selection/_condensed_nearest_neighbour.py in _fit_resample(self, X, y)
#     195                         # Classify all the element in S and avoid to test the
#     196                         # well classified elements
# ...

# %% [markdown]
# Deixei CNN rodando por um bom tempo mas nao terminava a execucao.

# %% [markdown]
# ## 3. Tomek Links

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with Tomek Links
from collections import Counter
from imblearn.under_sampling import TomekLinks
from matplotlib import pyplot
from numpy import where
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot before Tomek Links of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the undersampling method
undersample = TomekLinks()
# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot after Tomek Links of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284098, 1: 492})
# Counter({0: 284016, 1: 492})

# %% [markdown]
# ## 4. ENN

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the Edited Nearest Neighbor rule
from collections import Counter
from imblearn.under_sampling import EditedNearestNeighbours
from matplotlib import pyplot
from numpy import where
# summarize class distribution
counter = Counter(y)
print(counter)
# Before scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the undersampling method
undersample = EditedNearestNeighbours(n_neighbors=3)
# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# After scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 283322, 1: 492})

# %% [markdown]
# ## 5. OSS

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with One-Sided Selection
from collections import Counter
from imblearn.under_sampling import OneSidedSelection
from matplotlib import pyplot
from numpy import where
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the undersampling method
undersample = OneSidedSelection(n_neighbors=1, n_seeds_S=200)
# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 93263, 1: 492})

# %% [markdown]
# ## 6. NCR

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the neighborhood cleaning rule
from collections import Counter
from imblearn.under_sampling import NeighbourhoodCleaningRule
from matplotlib import pyplot
from numpy import where
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the undersampling method
undersample = NeighbourhoodCleaningRule(n_neighbors=3, threshold_cleaning=0.5)
# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 283251, 1: 492})

# %% [markdown]
# # OVERSAMPLING

# %% [markdown]
# SAO AS TECNICAS DE OVERSAMPLING:
#
# 1.   Random
# 2.   SMOTE
# 3.   Borderline-SMOTE
# 4.   ADASYN

# %% [markdown]
# ## 1. Random

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the neighborhood cleaning rule
from collections import Counter
from matplotlib import pyplot
from numpy import where
from imblearn.over_sampling import RandomOverSampler
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the oversampling method
oversample = RandomOverSampler(sampling_strategy='minority')
# transform the dataset
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 284315, 1: 284315})

# %% [markdown]
# ## 2. SMOTE

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the neighborhood cleaning rule
from collections import Counter
from matplotlib import pyplot
from numpy import where
from imblearn.over_sampling import SMOTE
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the oversampling method
oversample = SMOTE()
# transform the dataset
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 284315, 1: 284315})

# %% [markdown]
# ## 3. Bordeline-SMOTE

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the neighborhood cleaning rule
from collections import Counter
from matplotlib import pyplot
from numpy import where
from imblearn.over_sampling import BorderlineSMOTE
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the oversampling method
oversample = BorderlineSMOTE()
# transform the dataset
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 284315, 1: 284315})

# %% [markdown]
# ## 4. ADASYN

# %%
#Definindo dataset
X = df[['X1','X2']].values
y = df['Y'].values

# %%
# Undersample and plot imbalanced dataset with the neighborhood cleaning rule
from collections import Counter
from matplotlib import pyplot
from numpy import where
from imblearn.over_sampling import ADASYN
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# define the oversampling method
oversample = ADASYN()
# transform the dataset
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 284315, 1: 492})
# Counter({0: 284315, 1: 284170})
