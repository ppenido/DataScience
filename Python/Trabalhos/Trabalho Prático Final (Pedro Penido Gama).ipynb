# %% [markdown]
# # Trabalho Prático Final

# %% [markdown]
# Fazer a importação do arquivo disponível em https://raw.githubusercontent.com/assisarthur/puc/main/heart_2020_cleaned.csv. A base de dados traz informações de saúde de algumas pessoas.
#
# Colunas da base de dados:
#
# * HeartDisease: Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI)
# * BMI: Body Mass Index (BMI)
# * Smoking: Have you smoked at least 100 cigarettes in your entire life? [Note: 5 packs = 100 cigarettes]
# * AlcoholDrinking: Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week
# * Stroke: (Ever told) (you had) a stroke?
# * PhysicalHealth: Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30
# * MentalHealth: Thinking about your mental health, for how many days during the past 30 days was your mental health not good?
# * DiffWalking: Do you have serious difficulty walking or climbing stairs?
# * Sex: Are you male or female?
# * AgeCategory: Fourteen-level age category
# * Race: Imputed race/ethnicity value
# * Diabetic: (Ever told) (you had) diabetes?
# * PhysicalActivity: Adults who reported doing physical activity or exercise during the past 30 days other than their regular job
# * GenHealth: Would you say that in general your health is...
# * SleepTime: On average, how many hours of sleep do you get in a 24-hour period?
# * Asthma: (Ever told) (you had) asthma?
# * KidneyDisease: Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
# * SkinCancer: (Ever told) (you had) skin cancer?

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/assisarthur/puc/main/heart_2020_cleaned.csv")

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
#print coluna Sex
df["Sex"]
# Out:
# 0         Female
# 1         Female
# 2           Male
# 3         Female
# 4         Female
#            ...
# 319790      Male
# 319791      Male
# 319792    Female
# 319793    Female
# 319794    Female
# Name: Sex, Length: 319795, dtype: object

# %%
#numero de linhas
df.shape[0]
# Out:
# 319795

# %%
#quantidade total de dados semelhantes
df["Sex"].value_counts()
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %% [markdown]
# 1) Qual o percentual de homens e mulheres na base?

# %%
#Percentual de homens e mulheres na coluna Sexo
df["Sex"].value_counts()/df.shape[0]
# Out:
# Female    0.524727
# Male      0.475273
# Name: Sex, dtype: float64

# %% [markdown]
# 2) Informar quantas pessoas tiveram alguma doença e/ou lesão física há mais de 5 dias.

# %%
print(df[df["MentalHealth"]>=5].shape[0])
print(df[df["PhysicalHealth"]>=5].shape[0])
print(df[df["MentalHealth"]>=5].shape[0]+df[df["PhysicalHealth"]>=5].shape[0])
# Out:
# 72763
# 54752
# 127515

# %%
#Quantidade de pessoas que tiveram alguma doenca e/ou lesao fisica a mais de 5 dias
df[(df["MentalHealth"] >5) | (df["PhysicalHealth"] >5)].shape[0]
# Out:
# 86565

# %% [markdown]
# 3) Calcular a mediana do indíce de massa corporal (BMI).

# %%
df["BMI"].median()
# Out:
# 27.34

# %% [markdown]
# 4) Os percentis de 10 e 90% do tempo de sono.

# %%
print(df['SleepTime'].quantile(0.10))
print(df['SleepTime'].quantile(0.90))
# Out:
# 6.0
# 8.0

# %% [markdown]
# 5) Determinar a faixa etária com mais ocorrência de câncer de pele.

# %%
df["AgeCategory"].value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
#quantidade da faixa etaria com maior ocorrencia
df["AgeCategory"].value_counts().max()
# Out:
# 34151

# %%
#ID faixa etaria com maior ocorrencia
df["AgeCategory"].value_counts().idxmax()
# Out:
# '65-69'

# %%
#quantidade de pessoas com cancer de pele ou nao
df["SkinCancer"].value_counts()
# Out:
# No     289976
# Yes     29819
# Name: SkinCancer, dtype: int64

# %%
#Quantidade de pessoas com cancer de pele por faixa etaria
df[(df.SkinCancer == "Yes")].AgeCategory.value_counts()
# Out:
# 80 or older    6235
# 70-74          5565
# 75-79          4837
# 65-69          4608
# 60-64          3338
# 55-59          2188
# 50-54          1289
# 45-49           773
# 40-44           414
# 35-39           263
# 30-34           159
# 25-29            83
# 18-24            67
# Name: AgeCategory, dtype: int64

# %% [markdown]
# 6) Definir por sexo a quantidade de pessoas com e sem problemas cardíacos.

# %%
print("Quantidade de pessoas COM problema cardiacos separados por sexo:\n", df[(df.HeartDisease == "Yes")].Sex.value_counts(),"\n")
print("Quantidade de pessoas SEM problema cardiacos separados por sexo:\n", df[(df.HeartDisease == "No")].Sex.value_counts())
# Out:
# Quantidade de pessoas COM problema cardiacos separados por sexo:
#  Male      16139
# Female    11234
# Name: Sex, dtype: int64
#
# Quantidade de pessoas SEM problema cardiacos separados por sexo:
#  Female    156571
# Male      135851
# Name: Sex, dtype: int64

# %% [markdown]
# 7) Associe doença cardíaca com alguma outra doença na base.

# %%
#Fumantes com problema cardiaco
df[((df.HeartDisease == "Yes") & (df.Smoking == "Yes"))]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 5               Yes  28.87     Yes              No     No             6.0
# 10              Yes  34.30     Yes              No     No            30.0
# 35              Yes  32.98     Yes              No    Yes            10.0
# 43              Yes  30.23     Yes              No     No             6.0
# 45              Yes  20.37     Yes              No     No             3.0
# ...             ...    ...     ...             ...    ...             ...
# 319758          Yes  28.32     Yes              No     No             0.0
# 319767          Yes  36.21     Yes              No     No             0.0
# 319781          Yes  37.12     Yes              No     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# 8) Filtrar as pessoas que possuem mais de 3 tipos de doenças.

# %%
#Fumantes e alcolicos com diabetes
df[((df.Smoking == "Yes") & (df.AlcoholDrinking == "Yes") & (df.Diabetic == "Yes"))]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 505              No  23.24     Yes             Yes     No             0.0
# 1136             No  26.63     Yes             Yes     No             0.0
# 1291             No  25.73     Yes             Yes     No            10.0
# 1397             No  27.17     Yes             Yes     No             0.0
# 1496             No  27.44     Yes             Yes     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 316151           No  30.79     Yes             Yes     No             3.0
# 317142          Yes  29.05     Yes             Yes     No             0.0
# 317658           No  31.01     Yes             Yes     No             0.0
# 318583           No  32.61     Yes             Yes     No            30.0
# 318641           No  44.55     Yes             Yes     No             0.0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# 9) Renomeie os nomes das colunas para a tradução em português.

# %%
#total de colunas e o nome das colunas
print(df.columns.shape[0])
df.columns.values
# Out:
# 18
# array(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex',
#        'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth',
#        'SleepTime', 'Asthma', 'KidneyDisease', 'SkinCancer'], dtype=object)

# %%
df.rename(columns = {"HeartDisease":"Doença Cardíaca","BMI":"IMC","Smoking":"Fumar","AlcoholDrinking":"Beber Álcool","Stroke":"AVC","PhysicalHealth":"Saúde Física",
                    "MentalHealth":"Saúde Mental","DiffWalking":"Dificuldade de Andar","Sex":"Sexo","AgeCategory":"Faixa Etária","Race":"Raça","Diabetic":"Diabético",
                    "PhysicalActivity":"Ativo Fisicamente","GenHealth":"Saúde Geral","SleepTime":"Horas de Sono","Asthma":"Asma","KidneyDisease":"Doença Renal","SkinCancer":"Câncer de pele"}, inplace=True)

# %%
df.columns.values
# Out:
# array(['Doença Cardíaca', 'IMC', 'Fumar', 'Beber Álcool', 'AVC',
#        'Saúde Física', 'Saúde Mental', 'Dificuldade de Andar', 'Sexo',
#        'Faixa Etária', 'Raça', 'Diabético', 'Ativo Fisicamente',
#        'Saúde Geral', 'Horas de Sono', 'Asma', 'Doença Renal',
#        'Câncer de pele', 'IdadeMinima', 'Idademaxima'], dtype=object)

# %%
df.head()
# Out:
#   Doença Cardíaca    IMC Fumar Beber Álcool  AVC  Saúde Física  Saúde Mental  \
# 0              No  16.60   Yes           No   No           3.0          30.0
# 1              No  20.34    No           No  Yes           0.0           0.0
# 2              No  26.58   Yes           No   No          20.0          30.0
# 3              No  24.21    No           No   No           0.0           0.0
# 4              No  23.71    No           No   No          28.0           0.0
#
#   Dificuldade de Andar    Sexo Faixa Etária   Raça Diabético  \
# 0                   No  Female        55-59  White       Yes
# 1                   No  Female  80 or older  White        No
# 2                   No    Male        65-69  White       Yes
# 3                   No  Female        75-79  White        No
# 4                  Yes  Female        40-44  White        No
#
#   Ativo Fisicamente Saúde Geral  Horas de Sono Asma Doença Renal  \
# 0               Yes   Very good            5.0  Yes           No
# ...

# %% [markdown]
# 10) Salvar uma amostra da base em parquet e em csv e comparar o tamanho dos arquivos salvos.

# %%
from google.colab import drive
drive.mount ("/drive")
df.to_csv("/drive/MyDrive/df.csv")
df.to_parquet("/drive/MyDrive/df.parquet")
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# **A diferenca foi de 25,7 MB em .CSV para 1,8 MB em .PARQUET**

# %% [markdown]
# 11) Gerar 2 novas colunas, IdadeMinima e IdadeMaxima, baseando-se na faixa etária (AgeCategory).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/assisarthur/puc/main/heart_2020_cleaned.csv")

# %%
df.AgeCategory = df.AgeCategory.str.replace("80 or older", "80-80+")

# %%
IdadeMinima = []
for idademinima in df.AgeCategory:
  IdadeMinima.append(idademinima.split("-")[0])

IdadeMaxima = []
for idademaxima in df.AgeCategory:
  IdadeMaxima.append(idademaxima.split("-")[0])

# %%
df["IdadeMinima"] = df.AgeCategory.apply(lambda idademinima: idademinima.split("-")[0])
df["Idademaxima"] = df.AgeCategory.apply(lambda idademaxima: idademaxima.split("-")[1])

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# 12) Plotar um gráfico de barras apresentando o percentual de pessoas por faixa etária com dificuldade de andar.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df[(df.DiffWalking == "Yes")].AgeCategory.value_counts(normalize=True)*100
# Out:
# 80-80+    17.878856
# 70-74     13.931547
# 65-69     13.557757
# 60-64     13.447422
# 75-79     11.389327
# 55-59     10.470615
# 50-54      6.998424
# 45-49      4.291826
# 40-44      2.974555
# 35-39      2.181941
# 30-34      1.321774
# 25-29      0.819635
# 18-24      0.736321
# Name: AgeCategory, dtype: float64

# %%
(df[(df.DiffWalking == "Yes")].AgeCategory.value_counts(normalize=True)*100).plot.bar(x="Faixa Etaria", y="Dificuldade de andar", title="Correlação entre a dificuldade de andar e faixa etaria")

# %%
(df[(df.DiffWalking == "Yes")].AgeCategory.value_counts(normalize=True)*100).plot.barh(x="Faixa Etaria", y="Dificuldade de andar", title="Correlação entre a dificuldade de andar e faixa etaria")

# %% [markdown]
# Pedro Penido Gama
