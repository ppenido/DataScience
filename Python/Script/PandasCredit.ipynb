# %%
import pandas as pd

# %%
credit_df = pd.read_csv("Credit.csv")

# %%
credit_df
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
credit_df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
credit_df.tail()
# Out:
#     checking_status  duration                    credit_history  \
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount savings_status  employment  \
# 995  furniture/equipment           1736           <100      4<=X<7
# 996           'used car'           3857           <100      1<=X<4
# 997             radio/tv            804           <100         >=7
# 998             radio/tv           1845           <100      1<=X<4
# 999           'used car'           4576     100<=X<500  unemployed
#
#      installment_commitment       personal_status other_parties  ...  \
# 995                       3  'female div/dep/mar'          none  ...
# ...

# %%
credit_df[:8:2]
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 2   'no checking'        12  'critical/other existing credit'
# 4              <0        24              'delayed previously'
# 6   'no checking'        24                   'existing paid'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 2            education           2096                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
# 6  furniture/equipment           2835         500<=X<1000        >=7
#
#    installment_commitment personal_status other_parties  ...  \
# 0                       4   'male single'          none  ...
# 2                       2   'male single'          none  ...
# 4                       3   'male single'          none  ...
# ...

# %%
credit_df.shape
# Out:
# (1000, 21)

# %%
credit_df[["duration"]]
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
credit_df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
credit_df.loc[[1,3,5]]
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
# 5   'no checking'        36  'existing paid'            education
#
#    credit_amount      savings_status employment  installment_commitment  \
# 1           5951                <100     1<=X<4                       2
# 3           7882                <100     4<=X<7                       2
# 5           9055  'no known savings'     1<=X<4                       2
#
#         personal_status other_parties  ...   property_magnitude age  \
# 1  'female div/dep/mar'          none  ...        'real estate'  22
# 3         'male single'     guarantor  ...     'life insurance'  45
# 5         'male single'          none  ...  'no known property'  35
#
#    other_payment_plans     housing existing_credits                   job  \
# ...

# %%
credit_df.loc[1:4]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
# 4            'new car'           4870           <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# ...

# %%
credit_df.loc[credit_df["duration"]>=72]
# Out:
#     checking_status  duration   credit_history   purpose  credit_amount  \
# 677        0<=X<200        72  'existing paid'  radio/tv           5595
#
#     savings_status employment  installment_commitment personal_status  \
# 677     100<=X<500     1<=X<4                       2  'male mar/wid'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 677          none  ...                 car  24                 none     own
#
#     existing_credits      job num_dependents  own_telephone foreign_worker  \
# 677                1  skilled              1           none            yes
#
#     class
# 677   bad
#
# [1 rows x 21 columns]

# %%
credit_df.loc[credit_df["credit_amount"] >= 2319.5]
# Out:
#     checking_status  duration                    credit_history  \
# 1          0<=X<200        48                   'existing paid'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# 5     'no checking'        36                   'existing paid'
# 6     'no checking'        24                   'existing paid'
# ..              ...       ...                               ...
# 990   'no checking'        12  'critical/other existing credit'
# 993              <0        36                   'existing paid'
# 994   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 1               radio/tv           5951                <100      1<=X<4
# ...

# %%
credit_df.loc[credit_df['purpose'] == 'education']
# Out:
#     checking_status  duration                    credit_history    purpose  \
# 2     'no checking'        12  'critical/other existing credit'  education
# 5     'no checking'        36                   'existing paid'  education
# 36    'no checking'        48  'critical/other existing credit'  education
# 68    'no checking'        36                   'existing paid'  education
# 74               <0        36                   'existing paid'  education
# 87         0<=X<200        36                   'existing paid'  education
# 96    'no checking'        12  'critical/other existing credit'  education
# 111           >=200        15                   'existing paid'  education
# 131              <0        36              'delayed previously'  education
# 174              <0        21              'delayed previously'  education
# 195        0<=X<200         9  'critical/other existing credit'  education
# ...

# %%
credit_df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
credit1 = credit_df[['duration','savings_status']].loc[credit_df['credit_amount'] >= 4000]
credit1
# Out:
#      duration      savings_status
# 1          48                <100
# 3          42                <100
# 4          24                <100
# 5          36  'no known savings'
# 7          36                <100
# ..        ...                 ...
# 981        48                <100
# 983        36                <100
# 986        42                <100
# 988        24                <100
# 999        45          100<=X<500
#
# [246 rows x 2 columns]

# %%
credit_df.head()
# Out:
#   checking_status  Duracao                    credit_history  \
# 0              <0        6  'critical/other existing credit'
# 1        0<=X<200       48                   'existing paid'
# 2   'no checking'       12  'critical/other existing credit'
# 3              <0       42                   'existing paid'
# 4              <0       24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
credit_df.rename(columns={'duration':'Duracao'}, inplace=True)
